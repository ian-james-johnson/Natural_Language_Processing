# %%
import numpy as np
import pandas as pd

import requests
from bs4 import BeautifulSoup
import re

import acquire

# %%
acquire.parse_gulde_news()
# Out:
#                       title          date                  author  \
# 0     heart tell throughout   2000-03-11        By Timothy Garza
# 1   economy century thought   1990-03-03   By Catherine Mcintyre
# 2          people kid media   2012-02-21        By Barry Edwards
# 3   morning discussion ball   2008-08-30        By Albert Little
# 4           house me career   1995-08-10           By Sarah Shaw
# 5         cover pass degree   2004-12-27        By Rebecca Davis
# 6       first member little   1991-12-05   By Christopher Garcia
# 7      buy kitchen employee   1987-02-28    By Dr. Bruce Jackson
# 8         will certain deep   1990-11-30      By Dustin Robinson
# 9         Congress its poor   2006-08-10     By Christine Hoover
# 10      continue amount cup   2005-02-27        By Kevin Blevins
# 11         fly recently pay   2014-08-14        By Michelle Hall
#
#                                              contents
# 0   Task purpose edge section heart. Perhaps struc...
# 1   Citizen ask structure check face idea. Care ch...
# 2   They another lay able base base. Commercial ba...
# 3   Impact set list through. Newspaper address all...
# 4   True meeting half theory between fund.\nToday ...
# 5   Data former energy maybe world. Rest receive b...
# 6   Down though wonder true ability on. Store hand...
# 7   Benefit another left one nor.\nFly month any r...
# 8   Choice might two Republican evening computer p...
# 9   President modern administration onto wrong abi...
# 10  West recently station. Sit deal talk sign best...
# 11  Close college federal some source professional...

# %%
# Webscraping demo from Zach

# import requests
# from bs4 import BeautifulSoup
# def parse_news_article(article):
#     title = article.h2.text
#     date, author = article.select('.italic')[0].find_all('p')
#     return {'title':title, 'date':date.text, 'author':author.text}
# response = requests.get('https://web-scraping-demo.zgulde.net/news')
# soup = BeautifulSoup(response.text)
# articles = soup.select('.grid.gap-y-12 > div')
        # pd.DataFrame([parse_news_article(article) for article in articles])

# %%
acquire.parse_gulde_people()
# Out:
#                name                                            quote  \
# 0       Maria Smith  "Focused client-driven artificial intelligence"
# 1     Jessica Burke      "Public-key interactive Local Area Network"
# 2    Mary Barry PhD             "Ergonomic system-worthy definition"
# 3  Katrina Gonzalez        "Pre-emptive bandwidth-monitored support"
# 4  Nicholas Roberts            "Inverse context-sensitive algorithm"
# 5       John Miller                   "Integrated discrete intranet"
# 6      John Bridges        "Implemented user-facing functionalities"
# 7     Gerald Cooper               "Public-key multimedia initiative"
# 8    Brooke Herrera          "Devolved context-sensitive monitoring"
# 9        Mary Moody                       "Seamless 24hour matrices"
#
#                             email                phone  \
# 0       danielsmith@underwood.com     322.550.3501x015
# 1            melissa46@mckee.info  (295)597-2349x36617
# 2    bhoward@fischer-williams.com      +1-285-542-6399
# 3     danielstrickland@warren.net         604-660-9450
# 4  loriwilliams@peterson-ward.com   746.158.4151x86908
# 5         anthonyrubio@morgan.net         531.088.6865
# 6         davidgriffith@yahoo.com        (487)720-7197
# 7             henryalan@flynn.com   655.365.4568x30262
# 8   andrewshelton@costa-james.com        (812)132-6789
# 9                hliu@hotmail.com  (814)596-3660x42646
#
#                                              address
# 0           04872 Lopez Plaza East Rebecca, WA 81215
# 1  375 Elizabeth Station Apt. 011 New Karen, SC 9...
# 2  4672 Elizabeth Manors Lake Stephaniemouth, FL ...
# 3  7562 Douglas Manor Apt. 743 Chelsealand, KS 93529
# 4          9680 Johnny Alley New Johnmouth, MI 93515
# 5             9791 Soto Villages New Peter, UT 55390
# 6        1343 Parrish Shore Lindseychester, ME 50070
# 7   393 Delgado Key Apt. 431 Port Kristina, CT 47757
# 8  344 Alexander Turnpike Suite 309 Ashleefort, S...
# 9           364 Adam Stravenue North Donna, ME 58427

# %% [markdown]
# # Exercises
# 1. Codeup Blog Articles
#
# Visit Codeup's Blog and record the urls for at least 5 distinct blog posts. For each post, you should scrape at least the post's title and content.
# Encapsulate your work in a function named get_blog_articles that will return a list of dictionaries, with each dictionary representing one article.

# %%
acquire.get_blogs()
# Out:
#                                                title          date  \
# 0  Codeup’s Data Science Career Accelerator is Here!  Sep 30, 2018
# 1                                 Data Science Myths  Oct 31, 2018
# 2  Data Science VS Data Analytics: What’s The Dif...  Oct 17, 2018
# 3        10 Tips to Crush It at the SA Tech Job Fair  Aug 14, 2018
# 4  Competitor Bootcamps Are Closing. Is the Model...  Aug 14, 2018
#
#                         category  \
# 0                   Data Science
# 1                   Data Science
# 2                   Data Science
# 3  Tips for Prospective Students
# 4                    Codeup News
#
#                                              content
# 0  The rumors are true! The time has arrived. Cod...
# 1  By Dimitri Antoniou and Maggie Giust Data Scie...
# 2  By Dimitri Antoniou A week ago, Codeup launche...
# 3  The third bi-annual San Antonio Tech Job Fair ...
# 4    In recent news, DevBootcamp and The Iron Yar...

# %% [markdown]
# 2. News Articles
#
# We will now be scraping text data from inshorts, a website that provides a brief overview of many different topics.
# Write a function that scrapes the news articles for the following topics:
# - Business
# - Sports
# - Technology
# - Entertainment

# %%
acquire.get_news()
# Out:
#                                              headline publish_time  \
# 0         Facebook changes its company name to 'Meta'     12:20 am
# 1   Ether hits fresh record high above $4,400, sur...     12:52 pm
# 2   Microsoft overtakes Apple as world's most valu...     08:52 pm
# 3   People share Elon Musk's old 'meta for k' Twit...     04:28 pm
# 4   Shares of Canadian firm 'META' jump over 30% a...     01:54 pm
# ..                                                ...          ...
# 20  It's not just a revenge story: Shoojit Sircar ...     08:18 am
# 21  It's a big relief for everybody: Juhi Chawla o...     11:03 pm
# 22  Big B made video for mom after she died, I pla...     11:05 pm
# 23  Always tried to do something new & unique for ...     11:06 pm
# 24  Peter's bond with Doctor Strange not as intima...     11:14 pm
#
#          category                                            content
# 0        Business  Facebook on Thursday announced it's changing t...
# 1        Business  Ether, the world's second-largest cryptocurren...
# 2        Business  Microsoft Corp on Friday overtook Apple Inc to...
# 3        Business  After Facebook changed the company's name to '...
# 4        Business  The shares of a Canadian material science comp...
# ..            ...                                                ...
# 20  Entertainment  'Sardar Udham' director Shoojit Sircar said th...
# 21  Entertainment  Juhi Chawla, reacting to Aryan Khan's bail in ...
# 22  Entertainment  During his appearance on 'Kaun Banega Crorepat...
# 23  Entertainment  Emraan Hashmi said that he has always tried to...
# 24  Entertainment  Actor Benedict Cumberbatch said that the bond ...
#
# [100 rows x 4 columns]
